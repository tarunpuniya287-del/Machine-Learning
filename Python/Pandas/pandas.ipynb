# %%
import pandas as pd
import numpy as np

# %%
dict1 = {
    "Name" :["John", "Tarun", "Amit", "Ravi"],
    "Age" :[23, 25, 26, 30],
    "City" :["New York", "Los Angeles", "Chicago", "Houston"],
    "Salary" :[70000, 80000, 75000, 90000],
    "skills" :["Python", "Java", "C++", "JavaScript"]
}
df = pd.DataFrame(dict1)
df
# Out:
#     Name  Age         City  Salary      skills
# 0   John   23     New York   70000      Python
# 1  Tarun   25  Los Angeles   80000        Java
# 2   Amit   26      Chicago   75000         C++
# 3   Ravi   30      Houston   90000  JavaScript

# %%
df.head(2) # Display the first two rows of the DataFrame
# Out:
#     Name  Age         City  Salary  skills
# 0   John   23     New York   70000  Python
# 1  Tarun   25  Los Angeles   80000    Java

# %%
df.tail(2) # Display the last two rows of the DataFrame
# Out:
#    Name  Age     City  Salary      skills
# 2  Amit   26  Chicago   75000         C++
# 3  Ravi   30  Houston   90000  JavaScript

# %%
df.describe() # Get a statistical summary of the DataFrame
# Out:
#             Age        Salary
# count   4.00000      4.000000
# mean   26.00000  78750.000000
# std     2.94392   8539.125638
# min    23.00000  70000.000000
# 25%    24.50000  73750.000000
# 50%    25.50000  77500.000000
# 75%    27.00000  82500.000000
# max    30.00000  90000.000000

# %%
Tarun = pd.read_csv("Tarun.csv")
Tarun
# Out:
#     Name  Age         City  Salary      skills
# 0   Ajay   86        Delhi   70000      Python
# 1  Tarun   25  Los Angeles   80000        Java
# 2   Amit   26      Chicago   75000         C++
# 3   Ravi   30      Houston   90000  JavaScript

# %%
import pandas as pd
dict1 = {
    "Name" :["John", "Tarun", "Amit", "Ravi"],
    "Age" :[23, 25, 26, 30],
    "City" :["New York", "Los Angeles", "Chicago", "Houston"],
    "Salary" :[70000, 80000, 75000, 90000],
    "skills" :["Python", "Java", "C++", "JavaScript"]
}
s = pd.Series(dict1)
print(s)
# Out:
# Name                      [John, Tarun, Amit, Ravi]
# Age                                [23, 25, 26, 30]
# City      [New York, Los Angeles, Chicago, Houston]
# Salary                 [70000, 80000, 75000, 90000]
# skills              [Python, Java, C++, JavaScript]
# dtype: object
