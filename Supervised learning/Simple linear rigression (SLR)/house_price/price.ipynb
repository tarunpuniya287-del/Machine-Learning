# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('house.csv')
df.head()
# Out:
#    Area_sqft  Price_INR
# 0       3674   21807160
# 1       1360    8239879
# 2       1794   10484884
# 3       1630    9303247
# 4       1595    9094300

# %%
plt.scatter(df['Area_sqft'],df['Price_INR'])
plt.xlabel('Area_sqft')
plt.ylabel('Price_INR')
# Out:
# Text(0, 0.5, 'Price_INR')

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#     Area_sqft
# 83       3961
# 30       3885
# 56       1797
# 24       2933
# 16        630
# 23       3353
# 2        1794
# 27       2824
# 28       1684
# 13       3944
# 99       1775
# 92        701
# 76       2753
# 14       3671
# 0        3674
# 21       2015
# 3        1630
# 29        959
# 61        741
# 79       2085

# %%
y_test
# Out:
# 83    24038838
# 30    23290754
# 56    10738551
# 24    17553808
# 16     3842332
# 23    19738151
# 2     10484884
# 27    17092663
# 28    10307550
# 13    24090075
# 99    10474767
# 92     4433270
# 76    16236969
# 14    22042588
# 0     21807160
# 21    11892918
# 3      9303247
# 29     5390330
# 61     4437234
# 79    12978140
# Name: Price_INR, dtype: int64

# %%
plt.scatter(df['Area_sqft'],df['Price_INR'])
plt.plot(x_train, lr.predict(x_train),color='red')
plt.xlabel('Area_sqft')
plt.ylabel('Price_INR')
# Out:
# Text(0, 0.5, 'Price_INR')

# %%
lr.predict(x_test.iloc[0].values.reshape(1,1))
# Out:
# c:\Users\Tarun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([23743079.73450929])

# %%
m=lr.coef_
lr.coef_
# Out:
# array([5996.73818403])

# %%
b=lr.intercept_
lr.intercept_
# Out:
# np.float64(-10000.212441114709)

# %%
m*2500+b
# Out:
# array([14981845.24763867])

# %%
m*15+b
# Out:
# array([79950.86031936])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
y_pred=lr.predict(x_test)

# %%
y_test.values
# Out:
# array([24038838, 23290754, 10738551, 17553808,  3842332, 19738151,
#        10484884, 17092663, 10307550, 24090075, 10474767,  4433270,
#        16236969, 22042588, 21807160, 11892918,  9303247,  5390330,
#         4437234, 12978140])

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
# Out:
# MAE 213968.29002209782

# %%
print("r2 score",r2_score(y_test,y_pred))
# Out:
# r2 score 0.998493840377421

# %%
print("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MSE 68645894093.94359

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 262003.6146581638
