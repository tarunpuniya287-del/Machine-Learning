# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sal=pd.read_csv('Salary.csv')
sal.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
plt.scatter(sal['YearsExperience'],sal['Salary'])
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
x=sal.iloc[:,0:1]
y=sal.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.15,random_state=1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#     YearsExperience
# 14              4.5
# 19              6.0
# 3               2.0
# 29             10.5
# 33             12.9
# 28             10.3

# %%
y_test
# Out:
# 14     61111
# 19     93940
# 3      43525
# 29    121872
# 33    135675
# 28    122391
# Name: Salary, dtype: int64

# %%
plt.scatter(sal['YearsExperience'],sal['Salary'])
plt.plot(x_train,lr.predict(x_train),color='red')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
lr.predict(x_test.iloc[5].values.reshape(1,1))
# Out:
# c:\Users\Tarun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([118695.08662008])

# %%
m=lr.coef_
m
# Out:
# array([8723.41266706])

# %%
b=lr.intercept_
b
# Out:
# np.float64(28843.936149349815)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
y_pred=lr.predict(x_test)

# %%
y_test.values
# Out:
# array([ 61111,  93940,  43525, 121872, 135675, 122391])

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
print("R2 Score",r2_score(y_test,y_pred))
# Out:
# MAE 5556.457710624726
# MSE 44567116.64261727
# RMSE 6675.860741703445
# R2 Score 0.9613245083787975
