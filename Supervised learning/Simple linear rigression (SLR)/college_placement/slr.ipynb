# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('placement.csv')
df.head()
# Out:
#    CGPA  Package_LPA
# 0  8.07         9.23
# 1  6.32         4.67
# 2  8.54        15.09
# 3  9.28        16.74
# 4  7.03         6.12

# %%
plt.scatter(df['CGPA'],df['Package_LPA'])
plt.xlabel('CGPA')
plt.ylabel('Package_LPA (in LPA)')
# Out:
# Text(0, 0.5, 'Package_LPA (in LPA)')

# %%
X=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#     CGPA
# 36  9.21
# 47  5.30
# 28  5.82
# 9   8.89
# 13  5.45
# 0   8.07
# 44  5.44
# 46  8.80
# 39  6.27
# 23  5.48

# %%
y_test
# Out:
# 36    21.29
# 47     3.26
# 28     3.96
# 9      9.06
# 13     2.69
# 0      9.23
# 44     2.59
# 46    12.80
# 39     4.74
# 23     3.06
# Name: Package_LPA, dtype: float64

# %%
lr.predict(X_test.iloc[1].values.reshape(1,1))
# Out:
# c:\Users\Tarun\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-0.62580986])

# %%
plt.scatter(df['CGPA'],df['Package_LPA'])
plt.plot(X_train, lr.predict(X_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package_LPA (in LPA)')
# Out:
# Text(0, 0.5, 'Package_LPA (in LPA)')

# %%
m=lr.coef_
lr.coef_
# Out:
# array([5.51897387])

# %%
b=lr.intercept_
lr.intercept_
# Out:
# np.float64(-29.876371351763176)

# %%
m*5.67+b
# Out:
# array([1.41621047])

# %%
m*9.21+b
# Out:
# array([20.95337796])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
y_pred=lr.predict(X_test)

# %%
y_test.values
# Out:
# array([21.29,  3.26,  3.96,  9.06,  2.69,  9.23,  2.59, 12.8 ,  4.74,
#         3.06])

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
# Out:
# MAE 3.5023945164644834

# %%
print("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MSE 20.43307695224211

# %%
print("RMSE", np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 4.5202961133361725

# %%
print("R2 Score",r2_score(y_test,y_pred))
# Out:
# R2 Score 0.37747109645587584
